# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Carregue os dados da tarefa anterior

# %%
from pandas_datareader import data as web

import plotly.express as px
from plotly import graph_objects

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mat_tarefa01.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# #### 2. Média móvel
#
# 1. Faça uma média móvel  em 90 dias dos valores de fechamento ajustados dos ativos que você escolheu
# 2. Utilizando a fução ```rolling()```, calcule o desvio pardão desses ativos ao longo do tempo, utilizando a mesma janela móvel do item acima
# 2. Monte um gráfico de linhas para as médias móveis dos ativos da sua base
# 4. Monte um gráfico de linhas para os desvios padrão em janela móvel
# 5. Compare os dois gráficos que você fez com o da tarefa anterior. Veja se eles apontam conclusões semelhantes quanto aos períodos de maior volatilidade (variação) dos ativos.

# %%
df.set_index(['Date', 'level_1']).rolling(90).mean()
# Out:
#                      Adj Close       Close        High         Low  \
# Date       level_1
# 2023-01-03 AAPL            NaN         NaN         NaN         NaN
#            GOOGL           NaN         NaN         NaN         NaN
#            MSFT            NaN         NaN         NaN         NaN
# 2023-01-04 AAPL            NaN         NaN         NaN         NaN
#            GOOGL           NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# 2023-06-29 GOOGL    210.867351  210.956111  212.803555  208.905555
#            MSFT     211.133906  211.215111  213.052444  209.158778
# 2023-06-30 AAPL     211.370032  211.451556  213.291889  209.390333
#            GOOGL    211.357365  211.438889  213.285333  209.399222
#            MSFT     211.652254  211.733778  213.599778  209.693222
#
#                           Open        Volume
# Date       level_1
# 2023-01-03 AAPL            NaN           NaN
# ...

# %%
df_mean = df.set_index(['Date', 'level_1']).rolling(90).mean()
df_std = df.set_index(['Date', 'level_1']).rolling(90).std()

# %%
df_mean.head()
# Out:
#                     Adj Close  Close  High  Low  Open  Volume
# Date       level_1
# 2023-01-03 AAPL           NaN    NaN   NaN  NaN   NaN     NaN
#            GOOGL          NaN    NaN   NaN  NaN   NaN     NaN
#            MSFT           NaN    NaN   NaN  NaN   NaN     NaN
# 2023-01-04 AAPL           NaN    NaN   NaN  NaN   NaN     NaN
#            GOOGL          NaN    NaN   NaN  NaN   NaN     NaN

# %%
px.line(df_mean.reset_index(), x='Date', y='Adj Close', color='level_1')
# Out:
# <div>                            <div id="86a56722-e782-475a-a49b-6fbbdba58830" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86a56722-e782-475a-a49b-6fbbdba58830")) {                    Plotly.newPlot(                        "86a56722-e782-475a-a49b-6fbbdba58830",                        [{"hovertemplate":"level_1=AAPL<br>Date=%{x}<br>Adj Close=%{y}<extra></extra>","legendgroup":"AAPL","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AAPL","orientation":"v","showlegend":true,"x":["2023-01-03","2023-01-04","2023-01-05","2023-01-06","2023-01-09","2023-01-10","2023-01-11","2023-01-12","2023-01-13","2023-01-17","2023-01-18","2023-01-19","2023-01-20","2023-01-23","2023-01-24","2023-01-25","2023-01-26","2023-
# ...

# %%
px.line(df_std.reset_index(), x='Date', y='Adj Close', color='level_1')
# Out:
# <div>                            <div id="a4c03fd8-c009-468e-9239-12f42663193a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4c03fd8-c009-468e-9239-12f42663193a")) {                    Plotly.newPlot(                        "a4c03fd8-c009-468e-9239-12f42663193a",                        [{"hovertemplate":"level_1=AAPL<br>Date=%{x}<br>Adj Close=%{y}<extra></extra>","legendgroup":"AAPL","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AAPL","orientation":"v","showlegend":true,"x":["2023-01-03","2023-01-04","2023-01-05","2023-01-06","2023-01-09","2023-01-10","2023-01-11","2023-01-12","2023-01-13","2023-01-17","2023-01-18","2023-01-19","2023-01-20","2023-01-23","2023-01-24","2023-01-25","2023-01-26","2023-
# ...

# %% [markdown]
# #### 3. Gráfico de *candlestick*
# 1. Selecione o período dos últimos 60 dias (corridos) para um dos ativos da sua base
# 2. Monte um gráfico de *candlestick* para esses dados.

# %%
df_ = (df.copy()
          .pipe(lambda x: x.loc[x['level_1'] == 'AAPL'])
          .drop('level_1', axis=1)
          .set_index('Date')
      )

# %%
graph = {'x': df_.index,
         'open': df_.Open,
         'close': df_.Close,
         'high': df_.High,
         'low': df_.Low,
         'type': 'candlestick',
         'name': 'AAPL',
         'showlegend': True
        }

# %%
from plotly import graph_objects
from plotly.graph_objs import Layout

layout = Layout(
            paper_bgcolor = 'rgba(0,0,0,0)',
            plot_bgcolor='rgba(0,0,0,0)')

grafico = graph_objects.Figure(data = [graph],
                              layout_title = 'Apple',
                              layout=layout
                              )

grafico.update_xaxes(showgrid=True, gridwidth=1, gridcolor='Lightgrey')
grafico.update_yaxes(showgrid=True, gridwidth=1, gridcolor='Lightgrey')
grafico
# Out:
# <div>                            <div id="c58fcb08-e0e0-4cec-bd41-231470d5d793" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c58fcb08-e0e0-4cec-bd41-231470d5d793")) {                    Plotly.newPlot(                        "c58fcb08-e0e0-4cec-bd41-231470d5d793",                        [{"close":[125.06999969482422,126.36000061035156,125.0199966430664,129.6199951171875,130.14999389648438,130.72999572753906,133.49000549316406,133.41000366210938,134.75999450683594,135.94000244140625,135.2100067138672,135.27000427246094,137.8699951171875,141.11000061035156,142.52999877929688,141.86000061035156,143.9600067138672,145.92999267578125,143.0,144.2899932861328,145.42999267578125,150.82000732421875,154.5,151.72999572753906,154.64999389648438,151.9199981689
# ...
